# %% [markdown]
# -------------------------------------
# > ***Name:*** Mubanga Nsofu <br>
# > ***Learner Id:*** 149050 <br>
# > ***Course:*** BAN6800 (Business Analytics Capstone) <br>
# > ***Assignment Four:*** Business Analytics Model <br>
# > ***Lecturer:*** Professor Raphael Wanjiku <br>
# > ***Institution:*** Nexford University <br>
# > ***Date:*** 30th May 2025

# %% [markdown]
# -------------------------------------------
# > ***INTRODUCTION*** <br>
#
# > This notebook implements a supervised learning model, to help Takealot predict customer online purchasing Intent. This will ultimately help Takealot compete better in South Africa. <br/>The code below implements a supervised Learning Pipeline, from the realm of classification, for Customer online purchasing intent for Takealot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
#from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_auc_score, roc_curve, precision_recall_curve
from imblearn.over_sampling import SMOTE
from sklearn.pipeline import Pipeline, make_pipeline
import optuna
import shap
import joblib

# %% [markdown]
# ------------------
# ***LOAD DATASET FROM MILESTONE ONE***

# %%
data_frame = pd.read_csv('online_shoppers_Intention_cleaned.csv')

# %%
data_frame
# Out:
#        Administrative  Administrative_Duration  Informational  Informational_Duration  ProductRelated  ProductRelated_Duration  \
# 0           -0.696993                -0.457191      -0.396478               -0.244931       -0.691003                -0.624348
# 1           -0.696993                -0.457191      -0.396478               -0.244931       -0.668518                -0.590903
# 2           -0.696993                -0.457191      -0.396478               -0.244931       -0.691003                -0.624348
# 3           -0.696993                -0.457191      -0.396478               -0.244931       -0.668518                -0.622954
# 4           -0.696993                -0.457191      -0.396478               -0.244931       -0.488636                -0.296430
# ...               ...                      ...            ...                     ...             ...                      ...
# 12325        0.206173                 0.363075      -0.396478               -0.244931        0.478227                 0.307822
# 12326       -0.696993                -0.457191      -0.396478               -0.244931       -0.601062                -0.380957
# 12327       -0.696993                -0.457191      -0.396478               -0.244931       -0.578577                -0.528063
# 12328        0.507228                -0.032916      -0.396478               -0.244931       -0.376210                -0.443536
# 12329       -0.696993                -0.457191      -0.396478               -0.244931       -0.646033                -0.613243
#
#        BounceRates  ExitRates  PageValues  SpecialDay  ...  OperatingSystems   Browser    Region  TrafficType   Weekend  Revenue  \
# 0         3.667189   3.229316   -0.317178   -0.308821  ...         -1.233426 -0.790293 -0.894178    -0.762629 -0.550552        0
# 1        -0.457683   1.171473   -0.317178   -0.308821  ...         -0.136078 -0.207952 -0.894178    -0.514182 -0.550552        0
# 2         3.667189   3.229316   -0.317178   -0.308821  ...          2.058618 -0.790293  2.437081    -0.265735 -0.550552        0
# 3         0.573535   1.994610   -0.317178   -0.308821  ...          0.961270 -0.207952 -0.477771    -0.017289 -0.550552        0
# 4        -0.045196   0.142551   -0.317178   -0.308821  ...          0.961270  0.374389 -0.894178    -0.017289  1.816360        0
# ...            ...        ...         ...         ...  ...               ...       ...       ...          ...       ...      ...
# 12325    -0.310366  -0.288966    0.342125   -0.308821  ...          2.058618  2.121412 -0.894178    -0.762629  1.816360        0
# 12326    -0.457683  -0.447364   -0.317178   -0.308821  ...          0.961270 -0.207952 -0.894178     0.976499  1.816360        0
# 12327     1.261014   0.897093   -0.317178   -0.308821  ...          0.961270 -0.207952 -0.894178     2.218733  1.816360        0
# 12328    -0.457683  -0.453140   -0.317178   -0.308821  ...         -0.136078 -0.207952 -0.061364     1.721839 -0.550552        0
# 12329    -0.457683   0.485525   -0.317178   -0.308821  ...          0.961270 -0.207952 -0.894178    -0.514182  1.816360        0
#
#        VisitorType_Other  VisitorType_Returning_Visitor  Total_Duration  Interaction_Intensity
# 0              -0.083316                       0.410621       -0.642894              -0.113505
# 1              -0.083316                       0.410621       -0.611486              -0.113505
# 2              -0.083316                       0.410621       -0.642894              -0.113505
# 3              -0.083316                       0.410621       -0.641585              -0.113505
# 4              -0.083316                       0.410621       -0.334952              -0.113505
# ...                  ...                            ...             ...                    ...
# 12325          -0.083316                       0.410621        0.303651              -0.040118
# 12326          -0.083316                       0.410621       -0.414330              -0.113505
# 12327          -0.083316                       0.410621       -0.552474              -0.113505
# 12328          -0.083316                       0.410621       -0.436290              -0.113505
# 12329          -0.083316                      -2.435336       -0.632466              -0.113505
#
# [12330 rows x 21 columns]

# %% [markdown]
# ----------------------
# ***SPLIT FEATURES AND TARGET***

# %%
X = data_frame.drop(columns=["Revenue"])
y = data_frame["Revenue"].astype(int)

# %% [markdown]
# ------------
# ***APPLY SMOTE FOR CLASS BALANCING***

# %% [markdown]
# Synthetic Mionroty Over-sampling technique (SMOTE) generates sythetic instances of the minority class and helps to balance the class (Tamanna, 2023). <br/> Google (2024) demonstrate in their tutorial how to classify highly imbalanced data.

# %%
smote = SMOTE(random_state=42)
X_balanced, y_balanced = smote.fit_resample(X, y)

# %% [markdown]
# -----------------
# ***SPLIT TRAIN AND TEST SETS***

# %%
X_train, X_test, y_train, y_test = train_test_split(X_balanced, y_balanced, test_size=0.3, random_state=42, stratify=y_balanced)

# %% [markdown]
# ------------------
# ***LOGISTIC REGRESSION MODEL IMPLEMENTATION WITH STRATIFIED CROSS VALDIATION AND TUNING WITH OPTUNA***

# %%
def objective_logreg(trial):
    C = trial.suggest_float("C", 0.001, 10.0, log=True)
    # Use only 'l2' since 'lbfgs' supports it
    model = make_pipeline(
        LogisticRegression(
            C=C,
            penalty="l2",  # Fixed
            class_weight='balanced',
            solver='lbfgs',
            max_iter=500,
            random_state=42
        )
    )
    score = cross_val_score(model, X_train, y_train, cv=StratifiedKFold(n_splits=5), scoring='roc_auc', n_jobs=-1).mean()
    return score

study_logreg = optuna.create_study(direction='maximize')
study_logreg.optimize(objective_logreg, n_trials=30)
# Out:
# [I 2025-06-01 01:16:50,426] A new study created in memory with name: no-name-0306623b-a3eb-4866-8009-be2f333f0d27
# [I 2025-06-01 01:16:50,532] Trial 0 finished with value: 0.9084017728828335 and parameters: {'C': 0.3007301923543918}. Best is trial 0 with value: 0.9084017728828335.
# [I 2025-06-01 01:16:50,615] Trial 1 finished with value: 0.8967714370794905 and parameters: {'C': 0.001794112117324599}. Best is trial 0 with value: 0.9084017728828335.
# [I 2025-06-01 01:16:50,711] Trial 2 finished with value: 0.9083951555012739 and parameters: {'C': 0.28535207664780365}. Best is trial 0 with value: 0.9084017728828335.
# [I 2025-06-01 01:16:50,796] Trial 3 finished with value: 0.90852966097428 and parameters: {'C': 1.0499754227534306}. Best is trial 3 with value: 0.90852966097428.
# [I 2025-06-01 01:16:50,893] Trial 4 finished with value: 0.9085068597791233 and parameters: {'C': 0.7704848769033256}. Best is trial 3 with value: 0.90852966097428.
# [I 2025-06-01 01:16:50,983] Trial 5 finished with value: 0.9067111757504615 and parameters: {'C': 0.022630073946156952}. Best is trial 3 with value: 0.90852966097428.
# [I 2025-06-01 01:16:51,079] Trial 6 finished with value: 0.9085238348013851 and parameters: {'C': 0.9484197843014411}. Best is trial 3 with value: 0.90852966097428.
# [I 2025-06-01 01:16:51,196] Trial 7 finished with value: 0.9084018448108939 and parameters: {'C': 0.3001498001654451}. Best is trial 3 with value: 0.90852966097428.
# [I 2025-06-01 01:16:51,318] Trial 8 finished with value: 0.9076572455293114 and parameters: {'C': 0.04987663549533626}. Best is trial 3 with value: 0.90852966097428.
# [I 2025-06-01 01:16:51,428] Trial 9 finished with value: 0.9081494492468412 and parameters: {'C': 0.11469950951200668}. Best is trial 3 with value: 0.90852966097428.
# [I 2025-06-01 01:16:51,533] Trial 10 finished with value: 0.9085632513785014 and parameters: {'C': 7.505153764112771}. Best is trial 10 with value: 0.9085632513785014.
# [I 2025-06-01 01:16:51,639] Trial 11 finished with value: 0.9085644022274681 and parameters: {'C': 9.13141853196565}. Best is trial 11 with value: 0.9085644022274681.
# [I 2025-06-01 01:16:51,746] Trial 12 finished with value: 0.9085646180116494 and parameters: {'C': 9.309602412404614}. Best is trial 12 with value: 0.9085646180116494.
# [I 2025-06-01 01:16:51,851] Trial 13 finished with value: 0.90856468993971 and parameters: {'C': 9.545557812255844}. Best is trial 13 with value: 0.90856468993971.
# [I 2025-06-01 01:16:51,955] Trial 14 finished with value: 0.9085569936372437 and parameters: {'C': 3.8194082639715186}. Best is trial 13 with value: 0.90856468993971.
# [I 2025-06-01 01:16:52,060] Trial 15 finished with value: 0.9085547638673704 and parameters: {'C': 2.987878454875035}. Best is trial 13 with value: 0.90856468993971.
# [I 2025-06-01 01:16:52,162] Trial 16 finished with value: 0.9040438674854958 and parameters: {'C': 0.00750431305270364}. Best is trial 13 with value: 0.90856468993971.
# [I 2025-06-01 01:16:52,278] Trial 17 finished with value: 0.9085518867449531 and parameters: {'C': 2.360669167558911}. Best is trial 13 with value: 0.90856468993971.
# [I 2025-06-01 01:16:52,384] Trial 18 finished with value: 0.9085644022274681 and parameters: {'C': 9.258943648091774}. Best is trial 13 with value: 0.90856468993971.
# [I 2025-06-01 01:16:52,485] Trial 19 finished with value: 0.9085482903419315 and parameters: {'C': 1.9751043619057058}. Best is trial 13 with value: 0.90856468993971.
# [I 2025-06-01 01:16:52,574] Trial 20 finished with value: 0.8966327597789794 and parameters: {'C': 0.0017603891413468403}. Best is trial 13 with value: 0.90856468993971.
# [I 2025-06-01 01:16:52,673] Trial 21 finished with value: 0.908564833795831 and parameters: {'C': 9.990502072074493}. Best is trial 21 with value: 0.908564833795831.
# [I 2025-06-01 01:16:52,771] Trial 22 finished with value: 0.9085582883423315 and parameters: {'C': 4.428707340215241}. Best is trial 21 with value: 0.908564833795831.
# [I 2025-06-01 01:16:52,892] Trial 23 finished with value: 0.9085647618677705 and parameters: {'C': 9.836488901888545}. Best is trial 21 with value: 0.908564833795831.
# [I 2025-06-01 01:16:52,996] Trial 24 finished with value: 0.9085431834496409 and parameters: {'C': 1.550076498281145}. Best is trial 21 with value: 0.908564833795831.
# [I 2025-06-01 01:16:53,101] Trial 25 finished with value: 0.9085595830474194 and parameters: {'C': 4.774591999636943}. Best is trial 21 with value: 0.908564833795831.
# [I 2025-06-01 01:16:53,199] Trial 26 finished with value: 0.9084991634766573 and parameters: {'C': 0.690145163242723}. Best is trial 21 with value: 0.908564833795831.
# [I 2025-06-01 01:16:53,306] Trial 27 finished with value: 0.9085556270040955 and parameters: {'C': 3.3223699119492722}. Best is trial 21 with value: 0.908564833795831.
# [I 2025-06-01 01:16:53,405] Trial 28 finished with value: 0.908560518112205 and parameters: {'C': 5.095209876872753}. Best is trial 21 with value: 0.908564833795831.
# [I 2025-06-01 01:16:53,506] Trial 29 finished with value: 0.9084647099357106 and parameters: {'C': 0.4578630437304987}. Best is trial 21 with value: 0.908564833795831.

# %%
print("\nBest parameters for Logistic Regression:", study_logreg.best_params)

# Final model using best parameters
best_logreg_model = make_pipeline(
    LogisticRegression(
        C=study_logreg.best_params['C'],
        penalty='l2',
        class_weight='balanced',
        solver='lbfgs',
        max_iter=500,
        random_state=42
    )
)
best_logreg_model.fit(X_train, y_train)
y_pred_logreg = best_logreg_model.predict(X_test)
print("\nLogistic Regression Classification Report:\n", classification_report(y_test, y_pred_logreg))
print("Logistic Regression ROC AUC:", roc_auc_score(y_test, best_logreg_model.predict_proba(X_test)[:, 1]))
# Out:
# Best parameters for Logistic Regression: {'C': 9.990502072074493}
#
# Logistic Regression Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.89      0.84      2085
#            1       0.88      0.75      0.81      2084
#
#     accuracy                           0.82      4169
#    macro avg       0.83      0.82      0.82      4169
# weighted avg       0.83      0.82      0.82      4169
#
# Logistic Regression ROC AUC: 0.902555038502787

# %% [markdown]
# ---------------------
# ***XGBoost CLASSIFIER MODEL WITH REGULARIZATION AND ALSO USING OPTUNA FOR HYPERPARAMETER TUNING***

# %%
def objective_xgb(trial):
    param = {
        "verbosity": 0,
        "objective": "binary:logistic",
        "eval_metric": "logloss",
        "use_label_encoder": False,
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),
        "n_estimators": trial.suggest_int("n_estimators", 100, 500),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
        "reg_alpha": trial.suggest_float("reg_alpha", 0, 1.0), # To prevent overfitting
        "reg_lambda": trial.suggest_float("reg_lambda", 1.0, 10.0) # To prevent overfitting
    }
    model = xgb.XGBClassifier(**param)
    #score = cross_val_score(model, X_train, y_train, scoring="roc_auc", cv=3, n_jobs=-1)
    score = cross_val_score(model, X_train, y_train, scoring="roc_auc",cv=StratifiedKFold(n_splits=5), n_jobs=-1)
    return score.mean()

study_xgb = optuna.create_study(direction="maximize")
study_xgb.optimize(objective_xgb, n_trials=50)

print("Best Hyperparameters for XGBoost:", study_xgb.best_params)

best_xgb = xgb.XGBClassifier(**study_xgb.best_params, early_stopping_rounds=10, eval_metric="logloss")
best_xgb.fit(X_train, y_train, eval_set=[(X_test, y_test)], verbose=False)
y_pred_xgb = best_xgb.predict(X_test)
print("\nXGBoost Classification Report:\n", classification_report(y_test, y_pred_xgb))
print("XGBoost ROC AUC:", roc_auc_score(y_test, best_xgb.predict_proba(X_test)[:, 1]))
# Out:
# [I 2025-06-01 00:47:17,410] A new study created in memory with name: no-name-4bd94372-d3c2-4d0f-8922-a0786114fdf9
# [I 2025-06-01 00:47:20,904] Trial 0 finished with value: 0.9876316822966341 and parameters: {'max_depth': 6, 'learning_rate': 0.10841330033264467, 'n_estimators': 237, 'subsample': 0.9335530567784569, 'colsample_bytree': 0.8290923689365186, 'reg_alpha': 0.12339756319629136, 'reg_lambda': 1.253510032518403}. Best is trial 0 with value: 0.9876316822966341.
# [I 2025-06-01 00:47:26,460] Trial 1 finished with value: 0.9838779366428874 and parameters: {'max_depth': 10, 'learning_rate': 0.015290076143139144, 'n_estimators': 284, 'subsample': 0.9081429389941008, 'colsample_bytree': 0.940310305230957, 'reg_alpha': 0.42635940665804495, 'reg_lambda': 2.2815842142585305}. Best is trial 0 with value: 0.9876316822966341.
# [I 2025-06-01 00:47:27,444] Trial 2 finished with value: 0.9696156811803107 and parameters: {'max_depth': 3, 'learning_rate': 0.0251564477291042, 'n_estimators': 244, 'subsample': 0.6217621023513394, 'colsample_bytree': 0.7704531692250681, 'reg_alpha': 0.05452583083104168, 'reg_lambda': 7.129216877198762}. Best is trial 0 with value: 0.9876316822966341.
# [I 2025-06-01 00:47:27,859] Trial 3 finished with value: 0.982767798958194 and parameters: {'max_depth': 3, 'learning_rate': 0.17464323709180063, 'n_estimators': 103, 'subsample': 0.7866297156889008, 'colsample_bytree': 0.7198872523670704, 'reg_alpha': 0.24329178899358728, 'reg_lambda': 5.790638410939765}. Best is trial 0 with value: 0.9876316822966341.
# [I 2025-06-01 00:47:30,229] Trial 4 finished with value: 0.9859302959551973 and parameters: {'max_depth': 5, 'learning_rate': 0.029221842037220006, 'n_estimators': 466, 'subsample': 0.6325615742237464, 'colsample_bytree': 0.9933487097905642, 'reg_alpha': 0.9862099818128137, 'reg_lambda': 2.358864227752868}. Best is trial 0 with value: 0.9876316822966341.
# [I 2025-06-01 00:47:31,663] Trial 5 finished with value: 0.9795817814854295 and parameters: {'max_depth': 3, 'learning_rate': 0.02599555132342752, 'n_estimators': 436, 'subsample': 0.781185880526341, 'colsample_bytree': 0.8040223039727739, 'reg_alpha': 0.21029318185043067, 'reg_lambda': 2.124805804660957}. Best is trial 0 with value: 0.9876316822966341.
# [I 2025-06-01 00:47:32,651] Trial 6 finished with value: 0.9747045914558095 and parameters: {'max_depth': 6, 'learning_rate': 0.020271678775773044, 'n_estimators': 149, 'subsample': 0.9422858710886235, 'colsample_bytree': 0.6083795287359722, 'reg_alpha': 0.17162609952985297, 'reg_lambda': 2.7733019853282053}. Best is trial 0 with value: 0.9876316822966341.
# [I 2025-06-01 00:47:34,791] Trial 7 finished with value: 0.9870245375385356 and parameters: {'max_depth': 8, 'learning_rate': 0.034324742038765975, 'n_estimators': 237, 'subsample': 0.7366811903045143, 'colsample_bytree': 0.6941886306891192, 'reg_alpha': 0.08712899065245527, 'reg_lambda': 1.856235690451105}. Best is trial 0 with value: 0.9876316822966341.
# [I 2025-06-01 00:47:41,802] Trial 8 finished with value: 0.9847917466866338 and parameters: {'max_depth': 10, 'learning_rate': 0.011733647379419175, 'n_estimators': 490, 'subsample': 0.6777330926526124, 'colsample_bytree': 0.9688690656523532, 'reg_alpha': 0.13926275109475605, 'reg_lambda': 6.1770790499241155}. Best is trial 0 with value: 0.9876316822966341.
# [I 2025-06-01 00:47:46,435] Trial 9 finished with value: 0.9884690687761729 and parameters: {'max_depth': 9, 'learning_rate': 0.06604018469992505, 'n_estimators': 443, 'subsample': 0.6779094542789391, 'colsample_bytree': 0.706900623460762, 'reg_alpha': 0.6813419662333318, 'reg_lambda': 2.6895142510311674}. Best is trial 9 with value: 0.9884690687761729.
# [I 2025-06-01 00:47:49,758] Trial 10 finished with value: 0.9880264954203405 and parameters: {'max_depth': 8, 'learning_rate': 0.06913922968160081, 'n_estimators': 371, 'subsample': 0.8637540740879064, 'colsample_bytree': 0.6019533312805264, 'reg_alpha': 0.8303145284973857, 'reg_lambda': 9.909683344110999}. Best is trial 9 with value: 0.9884690687761729.
# [I 2025-06-01 00:47:53,248] Trial 11 finished with value: 0.9880306672478454 and parameters: {'max_depth': 8, 'learning_rate': 0.07334377734002648, 'n_estimators': 384, 'subsample': 0.8672129409208564, 'colsample_bytree': 0.6025229487768098, 'reg_alpha': 0.8251394817014827, 'reg_lambda': 9.944477838886083}. Best is trial 9 with value: 0.9884690687761729.
# [I 2025-06-01 00:47:56,686] Trial 12 finished with value: 0.9881648850086098 and parameters: {'max_depth': 8, 'learning_rate': 0.060285708433244614, 'n_estimators': 378, 'subsample': 0.9995570825412671, 'colsample_bytree': 0.6818065287793847, 'reg_alpha': 0.6842641557263771, 'reg_lambda': 3.9800680415031553}. Best is trial 9 with value: 0.9884690687761729.
# [I 2025-06-01 00:48:00,065] Trial 13 finished with value: 0.9876585833912355 and parameters: {'max_depth': 9, 'learning_rate': 0.2878067866814173, 'n_estimators': 382, 'subsample': 0.7093148185230427, 'colsample_bytree': 0.685155307760859, 'reg_alpha': 0.6115279428234842, 'reg_lambda': 4.42805540242926}. Best is trial 9 with value: 0.9884690687761729.
# [I 2025-06-01 00:48:02,751] Trial 14 finished with value: 0.9876207492314485 and parameters: {'max_depth': 7, 'learning_rate': 0.04699092131519336, 'n_estimators': 332, 'subsample': 0.9922086643113859, 'colsample_bytree': 0.8759558053047761, 'reg_alpha': 0.590179749949381, 'reg_lambda': 4.085159487136994}. Best is trial 9 with value: 0.9884690687761729.
# [I 2025-06-01 00:48:07,506] Trial 15 finished with value: 0.9882711227538665 and parameters: {'max_depth': 9, 'learning_rate': 0.11563362475234565, 'n_estimators': 440, 'subsample': 0.8536366379010424, 'colsample_bytree': 0.7445329389729566, 'reg_alpha': 0.7262520510600122, 'reg_lambda': 3.5383681117654175}. Best is trial 9 with value: 0.9884690687761729.
# [I 2025-06-01 00:48:12,334] Trial 16 finished with value: 0.9882406252562438 and parameters: {'max_depth': 9, 'learning_rate': 0.11634850185409959, 'n_estimators': 439, 'subsample': 0.8336424518718603, 'colsample_bytree': 0.7625664678407048, 'reg_alpha': 0.40430782169183394, 'reg_lambda': 3.4039456792133014}. Best is trial 9 with value: 0.9884690687761729.
# [I 2025-06-01 00:48:17,822] Trial 17 finished with value: 0.9879556462808157 and parameters: {'max_depth': 9, 'learning_rate': 0.13158260723673654, 'n_estimators': 498, 'subsample': 0.743568842698894, 'colsample_bytree': 0.8824364361021118, 'reg_alpha': 0.7578948765915704, 'reg_lambda': 5.100713888635282}. Best is trial 9 with value: 0.9884690687761729.
# [I 2025-06-01 00:48:22,164] Trial 18 finished with value: 0.9878771008388251 and parameters: {'max_depth': 10, 'learning_rate': 0.21047705966734956, 'n_estimators': 414, 'subsample': 0.668159335884911, 'colsample_bytree': 0.7455017237178289, 'reg_alpha': 0.9933301815833044, 'reg_lambda': 6.92716391239151}. Best is trial 9 with value: 0.9884690687761729.
# [I 2025-06-01 00:48:24,751] Trial 19 finished with value: 0.987987366555466 and parameters: {'max_depth': 7, 'learning_rate': 0.08245415053021651, 'n_estimators': 332, 'subsample': 0.8199313334498729, 'colsample_bytree': 0.6511010570530867, 'reg_alpha': 0.4983417609167291, 'reg_lambda': 3.3172737656481335}. Best is trial 9 with value: 0.9884690687761729.
# [I 2025-06-01 00:48:27,180] Trial 20 finished with value: 0.9872025594881023 and parameters: {'max_depth': 5, 'learning_rate': 0.044889545320597087, 'n_estimators': 455, 'subsample': 0.741331627322334, 'colsample_bytree': 0.8377835413370784, 'reg_alpha': 0.8523097960938213, 'reg_lambda': 1.1471395948766663}. Best is trial 9 with value: 0.9884690687761729.
# [I 2025-06-01 00:48:31,777] Trial 21 finished with value: 0.9882519179617313 and parameters: {'max_depth': 9, 'learning_rate': 0.10767647592728082, 'n_estimators': 423, 'subsample': 0.8434755203440256, 'colsample_bytree': 0.7689686955134941, 'reg_alpha': 0.3402079455179222, 'reg_lambda': 3.3421852232825437}. Best is trial 9 with value: 0.9884690687761729.
# [I 2025-06-01 00:48:36,319] Trial 22 finished with value: 0.9883460717928358 and parameters: {'max_depth': 9, 'learning_rate': 0.0924551675802681, 'n_estimators': 413, 'subsample': 0.8681337643721185, 'colsample_bytree': 0.7308440106673276, 'reg_alpha': 0.3378607592369926, 'reg_lambda': 4.973995471793641}. Best is trial 9 with value: 0.9884690687761729.
# [I 2025-06-01 00:48:40,432] Trial 23 finished with value: 0.9880797221850595 and parameters: {'max_depth': 10, 'learning_rate': 0.17393273478060597, 'n_estimators': 333, 'subsample': 0.8979075930268102, 'colsample_bytree': 0.7229044349403014, 'reg_alpha': 0.5629389233835678, 'reg_lambda': 4.715411716193}. Best is trial 9 with value: 0.9884690687761729.
# [I 2025-06-01 00:48:45,113] Trial 24 finished with value: 0.9882769489267613 and parameters: {'max_depth': 9, 'learning_rate': 0.08177772202011124, 'n_estimators': 409, 'subsample': 0.7991276947576177, 'colsample_bytree': 0.657859234059647, 'reg_alpha': 0.7297604928192136, 'reg_lambda': 5.446066286100192}. Best is trial 9 with value: 0.9884690687761729.
# [I 2025-06-01 00:48:48,412] Trial 25 finished with value: 0.9877402936678852 and parameters: {'max_depth': 7, 'learning_rate': 0.08592556052115606, 'n_estimators': 405, 'subsample': 0.8024219382231383, 'colsample_bytree': 0.6481689510630528, 'reg_alpha': 0.29711822520890785, 'reg_lambda': 8.07471941128867}. Best is trial 9 with value: 0.9884690687761729.
# [I 2025-06-01 00:48:52,894] Trial 26 finished with value: 0.9882654404370925 and parameters: {'max_depth': 8, 'learning_rate': 0.05172505748637743, 'n_estimators': 472, 'subsample': 0.7706176259153615, 'colsample_bytree': 0.6514822283791085, 'reg_alpha': 0.45675517629454454, 'reg_lambda': 5.310602584198573}. Best is trial 9 with value: 0.9884690687761729.
# [I 2025-06-01 00:48:56,618] Trial 27 finished with value: 0.9875763696181628 and parameters: {'max_depth': 9, 'learning_rate': 0.040732150641386224, 'n_estimators': 294, 'subsample': 0.671695292076523, 'colsample_bytree': 0.708849151657414, 'reg_alpha': 0.6678704369590258, 'reg_lambda': 6.500398138924116}. Best is trial 9 with value: 0.9884690687761729.
# [I 2025-06-01 00:49:01,230] Trial 28 finished with value: 0.9880187991178742 and parameters: {'max_depth': 10, 'learning_rate': 0.06009403847923394, 'n_estimators': 358, 'subsample': 0.606458286371677, 'colsample_bytree': 0.6710996084676205, 'reg_alpha': 0.5271749140550465, 'reg_lambda': 7.761366521132418}. Best is trial 9 with value: 0.9884690687761729.
# [I 2025-06-01 00:49:04,730] Trial 29 finished with value: 0.9877461198407801 and parameters: {'max_depth': 7, 'learning_rate': 0.10057577125875486, 'n_estimators': 404, 'subsample': 0.9529514348317494, 'colsample_bytree': 0.8016078660019824, 'reg_alpha': 0.9025677323928096, 'reg_lambda': 5.626869288171668}. Best is trial 9 with value: 0.9884690687761729.
# [I 2025-06-01 00:49:06,546] Trial 30 finished with value: 0.9869854086736611 and parameters: {'max_depth': 5, 'learning_rate': 0.08957021537772307, 'n_estimators': 347, 'subsample': 0.8945403232750131, 'colsample_bytree': 0.6276224251953143, 'reg_alpha': 0.36919406514576886, 'reg_lambda': 8.948799839179106}. Best is trial 9 with value: 0.9884690687761729.
# [I 2025-06-01 00:49:11,512] Trial 31 finished with value: 0.9881698480447796 and parameters: {'max_depth': 9, 'learning_rate': 0.14219987389249997, 'n_estimators': 458, 'subsample': 0.8699833466476257, 'colsample_bytree': 0.7378036810217872, 'reg_alpha': 0.7220612411616014, 'reg_lambda': 3.76469790693259}. Best is trial 9 with value: 0.9884690687761729.
# [I 2025-06-01 00:49:16,214] Trial 32 finished with value: 0.9879147192144305 and parameters: {'max_depth': 9, 'learning_rate': 0.1495442299331946, 'n_estimators': 436, 'subsample': 0.8132391383186707, 'colsample_bytree': 0.7430255059551384, 'reg_alpha': 0.7671804322628306, 'reg_lambda': 4.657515514510864}. Best is trial 9 with value: 0.9884690687761729.
# [I 2025-06-01 00:49:21,685] Trial 33 finished with value: 0.9886145073143645 and parameters: {'max_depth': 10, 'learning_rate': 0.06973763762749624, 'n_estimators': 402, 'subsample': 0.8463721390093617, 'colsample_bytree': 0.7077675913782552, 'reg_alpha': 0.6375684948700637, 'reg_lambda': 2.74757969256041}. Best is trial 33 with value: 0.9886145073143645.
# [I 2025-06-01 00:49:25,382] Trial 34 finished with value: 0.988689672137515 and parameters: {'max_depth': 10, 'learning_rate': 0.06684093978102487, 'n_estimators': 263, 'subsample': 0.9241132613349358, 'colsample_bytree': 0.708082361844832, 'reg_alpha': 0.640595526980312, 'reg_lambda': 1.5964344404955964}. Best is trial 34 with value: 0.988689672137515.
# [I 2025-06-01 00:49:28,578] Trial 35 finished with value: 0.9877662237336706 and parameters: {'max_depth': 10, 'learning_rate': 0.03716240984165362, 'n_estimators': 212, 'subsample': 0.918633658492953, 'colsample_bytree': 0.6989889084148675, 'reg_alpha': 0.6566263557301668, 'reg_lambda': 1.6676859046856232}. Best is trial 34 with value: 0.988689672137515.
# [I 2025-06-01 00:49:32,963] Trial 36 finished with value: 0.9886892405691523 and parameters: {'max_depth': 10, 'learning_rate': 0.06573768277562783, 'n_estimators': 311, 'subsample': 0.8850003455298869, 'colsample_bytree': 0.7798172253614899, 'reg_alpha': 0.450527000929727, 'reg_lambda': 2.4364164620749986}. Best is trial 34 with value: 0.988689672137515.
# [I 2025-06-01 00:49:36,857] Trial 37 finished with value: 0.9886047970262062 and parameters: {'max_depth': 10, 'learning_rate': 0.06446805803630447, 'n_estimators': 271, 'subsample': 0.9644307151855429, 'colsample_bytree': 0.7879511430746264, 'reg_alpha': 0.4728091961005064, 'reg_lambda': 2.695597000555276}. Best is trial 34 with value: 0.988689672137515.
# [I 2025-06-01 00:49:41,265] Trial 38 finished with value: 0.9877591388197182 and parameters: {'max_depth': 10, 'learning_rate': 0.029980126990242766, 'n_estimators': 264, 'subsample': 0.971559902432733, 'colsample_bytree': 0.8265863302597741, 'reg_alpha': 0.4651521482842407, 'reg_lambda': 1.5201179194097343}. Best is trial 34 with value: 0.988689672137515.
# [I 2025-06-01 00:49:44,549] Trial 39 finished with value: 0.9882387551266726 and parameters: {'max_depth': 10, 'learning_rate': 0.052439123167207405, 'n_estimators': 213, 'subsample': 0.9246269851628307, 'colsample_bytree': 0.7852650127110334, 'reg_alpha': 0.5332878012962748, 'reg_lambda': 2.787626728153027}. Best is trial 34 with value: 0.988689672137515.
# [I 2025-06-01 00:49:49,101] Trial 40 finished with value: 0.984651774681035 and parameters: {'max_depth': 10, 'learning_rate': 0.017632872652838937, 'n_estimators': 267, 'subsample': 0.9609476978892348, 'colsample_bytree': 0.8311036479091509, 'reg_alpha': 0.6090756658996941, 'reg_lambda': 2.283469969879644}. Best is trial 34 with value: 0.988689672137515.
# [I 2025-06-01 00:49:52,304] Trial 41 finished with value: 0.9884141876660639 and parameters: {'max_depth': 10, 'learning_rate': 0.06664492673591958, 'n_estimators': 210, 'subsample': 0.8916210831777949, 'colsample_bytree': 0.7850807419391962, 'reg_alpha': 0.42206225141869114, 'reg_lambda': 2.764571755606747}. Best is trial 34 with value: 0.988689672137515.
# [I 2025-06-01 00:49:54,914] Trial 42 finished with value: 0.9883860997584655 and parameters: {'max_depth': 10, 'learning_rate': 0.06943436886044131, 'n_estimators': 172, 'subsample': 0.9427047031068079, 'colsample_bytree': 0.7175203142886926, 'reg_alpha': 0.6368952637637694, 'reg_lambda': 2.91888796980608}. Best is trial 34 with value: 0.988689672137515.
# [I 2025-06-01 00:49:56,406] Trial 43 finished with value: 0.9853201302185607 and parameters: {'max_depth': 4, 'learning_rate': 0.05218924708923127, 'n_estimators': 313, 'subsample': 0.9785265097260787, 'colsample_bytree': 0.8558326759706288, 'reg_alpha': 0.48491571033503167, 'reg_lambda': 2.0082521513552685}. Best is trial 34 with value: 0.988689672137515.
# [I 2025-06-01 00:50:00,451] Trial 44 finished with value: 0.9887545512480237 and parameters: {'max_depth': 10, 'learning_rate': 0.06088869158423401, 'n_estimators': 271, 'subsample': 0.9078764654954012, 'colsample_bytree': 0.7555527521397298, 'reg_alpha': 0.5523376142002429, 'reg_lambda': 1.1051381073017832}. Best is trial 44 with value: 0.9887545512480237.
# [I 2025-06-01 00:50:05,387] Trial 45 finished with value: 0.9881590588357149 and parameters: {'max_depth': 10, 'learning_rate': 0.03144728034748095, 'n_estimators': 274, 'subsample': 0.9113270946381261, 'colsample_bytree': 0.8131801206136745, 'reg_alpha': 0.5343987308676843, 'reg_lambda': 1.00791315858202}. Best is trial 44 with value: 0.9887545512480237.
# [I 2025-06-01 00:50:09,334] Trial 46 finished with value: 0.9886657200933915 and parameters: {'max_depth': 10, 'learning_rate': 0.05896096845126827, 'n_estimators': 248, 'subsample': 0.9365832630676575, 'colsample_bytree': 0.783230892890619, 'reg_alpha': 0.5647085149983935, 'reg_lambda': 1.408254437305192}. Best is trial 44 with value: 0.9887545512480237.
# [I 2025-06-01 00:50:12,153] Trial 47 finished with value: 0.987926155776039 and parameters: {'max_depth': 8, 'learning_rate': 0.0434383281211725, 'n_estimators': 250, 'subsample': 0.9355547021219273, 'colsample_bytree': 0.7617429020815146, 'reg_alpha': 0.573282278294363, 'reg_lambda': 1.450434620632497}. Best is trial 44 with value: 0.9887545512480237.
# [I 2025-06-01 00:50:16,178] Trial 48 finished with value: 0.9887354543479793 and parameters: {'max_depth': 10, 'learning_rate': 0.07592826537192567, 'n_estimators': 305, 'subsample': 0.8821199115425318, 'colsample_bytree': 0.7532127198781702, 'reg_alpha': 0.02213693306058384, 'reg_lambda': 1.913314752056128}. Best is trial 44 with value: 0.9887545512480237.
# [I 2025-06-01 00:50:21,268] Trial 49 finished with value: 0.9875547912000334 and parameters: {'max_depth': 10, 'learning_rate': 0.024282487136716904, 'n_estimators': 302, 'subsample': 0.8787988882181457, 'colsample_bytree': 0.9230902767228688, 'reg_alpha': 0.24846128704877135, 'reg_lambda': 1.8440131358973293}. Best is trial 44 with value: 0.9887545512480237.
# Best Hyperparameters for XGBoost: {'max_depth': 10, 'learning_rate': 0.06088869158423401, 'n_estimators': 271, 'subsample': 0.9078764654954012, 'colsample_bytree': 0.7555527521397298, 'reg_alpha': 0.5523376142002429, 'reg_lambda': 1.1051381073017832}
#
# XGBoost Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94      2085
#            1       0.94      0.95      0.94      2084
#
#     accuracy                           0.94      4169
#    macro avg       0.94      0.94      0.94      4169
# weighted avg       0.94      0.94      0.94      4169
#
# XGBoost ROC AUC: 0.9872434490027938

# %% [markdown]
# ------------------
# ***COMPARE XGBOOST VERSUS LOGISTIC REGRESSION CLASSIFIER TUNED MODELS FROM THE CLASSIFICATION REPORTS ABOVE***

# %% [markdown]
# > XGBoost outperforms the Logistic Regression classifier accross all the metrics: Precision (Class 1), Recall (Class 1),	F1-Score (Class 1)	and ROC AUC <br/>
# > Logistic Regression underperforms especially in recall for the positive class (only 75%) <br/>
# > XGBoost is the final predictive model to be deployed for predicting purchasing intent

# %% [markdown]
# ----------------
# ***EVALUATE OVERFITTING FOR XGBOOST MODEL***

# %%
# Evaluate overfitting
print("\nTrain Accuracy:", accuracy_score(y_train, best_xgb.predict(X_train)))
print("Train ROC AUC:", roc_auc_score(y_train, best_xgb.predict_proba(X_train)[:, 1]))

xgb_cv_model = xgb.XGBClassifier(**study_xgb.best_params, eval_metric="logloss", use_label_encoder=False)
cv_scores = cross_val_score(xgb_cv_model, X_train, y_train, cv=StratifiedKFold(n_splits=5), scoring='roc_auc')
print("\nCross-validated ROC AUC:", cv_scores.mean(), "+/-", cv_scores.std())
# Out:
# Train Accuracy: 0.9961619190404798
# Train ROC AUC: 0.9999213970223454
# C:\Users\Mubanga\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:59:34] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\Mubanga\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:59:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\Mubanga\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:59:36] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\Mubanga\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:59:38] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\Mubanga\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:59:38] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Cross-validated ROC AUC: 0.9887545512480237 +/- 0.0004330278684529945

# %% [markdown]
# > The model is well-regularised and shows excellent generalization due to early stopping and regularization <br/> High Training Accuracy &ROC AUC shows the model fits the training data very well. <br/> High Cross-validated ROC AUC shows the model generalizes to unseen data <br/> The Small std Dev in Cross Validation AUC shows consistent performance across folds which indicates stability of the model

# %% [markdown]
# -------------
# ***SHAP EXPLANATION***

# %%
explainer = shap.Explainer(best_xgb)
shap_values = explainer(X_test)
shap.summary_plot(shap_values, X_test, plot_type="bar")

# %% [markdown]
# > The SHAP summary plot shows interaction_intensity, Month and PageValues are the top drivers of purchasing intent. <br/>This behavior is typical of e-commerce behavior where high interaction, seasonal influence and product value correlate with higher purchasing likelihood.

# %% [markdown]
# -------------------
# ***ROC CURVE FOR XGBOOST***

# %%
# ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, best_xgb.predict_proba(X_test)[:, 1])
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f"XGBoost (AUC = {roc_auc_score(y_test, best_xgb.predict_proba(X_test)[:, 1]):.4f})")
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - XGBoost")
plt.legend(loc="lower right")
plt.grid()
plt.show()

# %% [markdown]
# > The AUC of ***98.72%*** depicts excellent separation between the classes. <br/>The curve is very close to the top-left corner: this signifies very minimal false positives(predict a customer will purchase and he or she doesnt) and false negatives (predict a customer will not purchase and he or she does infact purchase)

# %% [markdown]
# --------------
# ***PRECISION RECALL CURVE FOR XGBOOST BEST MODEL***

# %%
precision, recall, _ = precision_recall_curve(y_test, best_xgb.predict_proba(X_test)[:, 1])
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, label='Precision-Recall Curve')
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve - XGBoost")
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# > The Precision Recall curve stays high (Precision is almost 1) across varions Recall values, which confirms excellent preciosn across most thresholds. <br/>There is an observed steep drop near the end as  recall nears one- this is expected behavior<br/>
# > The chart enables Takealot to have confidence as the model has very low false positives and high predictive confidence which is ideal for an imbalanced classification.

# %% [markdown]
# ------------
# ***EXPORT THE XGBOOST BEST MODEL***

# %%
joblib.dump(best_xgb, "xgboost_model.joblib")
# Out:
# ['xgboost_model.joblib']

# %% [markdown]
# -------------
# ***REFERENCES***

# %% [markdown]
# > Google. (2024). Classification on imbalanced data. TensorFlow Core. https://www.tensorflow.org/tutorials/structured_data/imbalanced_data <br/>
#
# >Tamanna. (2023). Handling Imbalanced Datasets in Python: Methods and Procedures. Medium. https://medium.com/@tam.tamanna18/handling-imbalanced-datasets-in-python-methods-and-procedures-7376f99794de
